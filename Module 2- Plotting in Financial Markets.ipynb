# %% [markdown]
# # Module 2

# %% [markdown]
# ### Query 2.1
# Load the week2.csv file into a dataframe. What is the type of the Date column? Make sure it is of type datetime64. Convert the Date column to the index of the dataframe.
# Plot the closing price of each of the days for the entire time frame to get an idea of what the general outlook of the stock is.
#
# >Look out for drastic changes in this stock, you have the exact date when these took place, try to fetch the news for this day of this stock
#
# >This would be helpful if we are to train our model to take NLP inputs.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("week2.csv")
data
# Out:
#      Unnamed: 0    Symbol Series        Date  Prev Close  Open Price  \
# 0             0  MINDAIND     EQ  2017-05-15      495.65      495.95
# 1             1  MINDAIND     EQ  2017-05-16      517.90      523.70
# 2             2  MINDAIND     EQ  2017-05-17      545.60      555.00
# 3             3  MINDAIND     EQ  2017-05-18      560.10      556.95
# 4             4  MINDAIND     EQ  2017-05-19      545.25      549.70
# ..          ...       ...    ...         ...         ...         ...
# 489         490  MINDAIND     EQ  2019-05-07      351.60      354.90
# 490         491  MINDAIND     EQ  2019-05-08      347.05      350.00
# 491         492  MINDAIND     EQ  2019-05-09      350.35      352.00
# 492         493  MINDAIND     EQ  2019-05-10      342.00      344.75
# 493         494  MINDAIND     EQ  2019-05-13      345.15      350.00
#
#      High Price  Low Price  Last Price  Close Price  ...  \
# 0        522.00     495.90      522.00       517.90  ...
# 1        568.00     500.10      551.00       545.60  ...
# 2        571.00     541.15      559.00       560.10  ...
# 3        558.00     542.20      547.00       545.25  ...
# 4        588.80     547.00      560.00       560.80  ...
# ..          ...        ...         ...          ...  ...
# 489      354.90     346.00      346.35       347.05  ...
# 490      352.00     346.00      350.00       350.35  ...
# 491      352.30     340.15      342.95       342.00  ...
# 492      349.90     340.00      347.00       345.15  ...
# 493      354.95     340.50      347.50       344.95  ...
#
#      Total Traded Quantity      Turnover  No. of Trades  Deliverable Qty  \
# 0                   110264  5.677483e+07           3648            68819
# 1                  1185514  6.443668e+08          28000           220287
# 2                   465042  2.596686e+08          14208           181463
# 3                    90333  4.986314e+07           3951            47989
# 4                   371398  2.111632e+08          10466           184909
# ..                     ...           ...            ...              ...
# 489                  76556  2.669909e+07           6056            53021
# 490                  41823  1.462933e+07           1764            25157
# 491                  67267  2.322195e+07           2327            48953
# 492                  88441  3.052768e+07           3123            47078
# 493                 245445  8.485105e+07          11109           155350
#
#      % Dly Qt to Traded Qty  Month  Year        VWAP  Day_Perc_Change  \
# 0                     62.41      5  2017  517.900000         0.000000
# 1                     18.58      5  2017  543.242873         0.053485
# 2                     39.02      5  2017  547.694931         0.026576
# 3                     53.12      5  2017  547.575623        -0.026513
# 4                     49.79      5  2017  549.785474         0.028519
# ..                      ...    ...   ...         ...              ...
# 489                   69.26      5  2019  642.942796        -0.012941
# 490                   60.15      5  2019  642.782646         0.009509
# 491                   72.77      5  2019  642.518087        -0.023833
# 492                   53.23      5  2019  642.174597         0.009211
# 493                   63.29      5  2019  641.224835        -0.000579
#
#                    Trend
# 0    Slight or No change
# 1    Slight or No change
# 2    Slight or No change
# 3    Slight or No change
# 4    Slight or No change
# ..                   ...
# 489  Slight or No change
# 490  Slight or No change
# 491  Slight or No change
# 492  Slight or No change
# 493  Slight or No change
#
# [494 rows x 21 columns]

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
pd.to_datetime(data['Date'])
# Out:
# 0     2017-05-15
# 1     2017-05-16
# 2     2017-05-17
# 3     2017-05-18
# 4     2017-05-19
#          ...
# 489   2019-05-07
# 490   2019-05-08
# 491   2019-05-09
# 492   2019-05-10
# 493   2019-05-13
# Name: Date, Length: 494, dtype: datetime64[ns]

# %%
data.set_index('Date', inplace = True)
data
# Out:
#             Unnamed: 0    Symbol Series  Prev Close  Open Price  High Price  \
# Date
# 2017-05-15           0  MINDAIND     EQ      495.65      495.95      522.00
# 2017-05-16           1  MINDAIND     EQ      517.90      523.70      568.00
# 2017-05-17           2  MINDAIND     EQ      545.60      555.00      571.00
# 2017-05-18           3  MINDAIND     EQ      560.10      556.95      558.00
# 2017-05-19           4  MINDAIND     EQ      545.25      549.70      588.80
# ...                ...       ...    ...         ...         ...         ...
# 2019-05-07         490  MINDAIND     EQ      351.60      354.90      354.90
# 2019-05-08         491  MINDAIND     EQ      347.05      350.00      352.00
# 2019-05-09         492  MINDAIND     EQ      350.35      352.00      352.30
# 2019-05-10         493  MINDAIND     EQ      342.00      344.75      349.90
# 2019-05-13         494  MINDAIND     EQ      345.15      350.00      354.95
#
#             Low Price  Last Price  Close Price  Average Price  \
# Date
# 2017-05-15     495.90      522.00       517.90         514.90
# 2017-05-16     500.10      551.00       545.60         543.53
# 2017-05-17     541.15      559.00       560.10         558.38
# 2017-05-18     542.20      547.00       545.25         551.99
# 2017-05-19     547.00      560.00       560.80         568.56
# ...               ...         ...          ...            ...
# 2019-05-07     346.00      346.35       347.05         348.75
# 2019-05-08     346.00      350.00       350.35         349.79
# 2019-05-09     340.15      342.95       342.00         345.22
# 2019-05-10     340.00      347.00       345.15         345.18
# 2019-05-13     340.50      347.50       344.95         345.70
#
#             Total Traded Quantity      Turnover  No. of Trades  \
# Date
# 2017-05-15                 110264  5.677483e+07           3648
# 2017-05-16                1185514  6.443668e+08          28000
# 2017-05-17                 465042  2.596686e+08          14208
# 2017-05-18                  90333  4.986314e+07           3951
# 2017-05-19                 371398  2.111632e+08          10466
# ...                           ...           ...            ...
# 2019-05-07                  76556  2.669909e+07           6056
# 2019-05-08                  41823  1.462933e+07           1764
# 2019-05-09                  67267  2.322195e+07           2327
# 2019-05-10                  88441  3.052768e+07           3123
# 2019-05-13                 245445  8.485105e+07          11109
#
#             Deliverable Qty  % Dly Qt to Traded Qty  Month  Year        VWAP  \
# Date
# 2017-05-15            68819                   62.41      5  2017  517.900000
# 2017-05-16           220287                   18.58      5  2017  543.242873
# 2017-05-17           181463                   39.02      5  2017  547.694931
# 2017-05-18            47989                   53.12      5  2017  547.575623
# 2017-05-19           184909                   49.79      5  2017  549.785474
# ...                     ...                     ...    ...   ...         ...
# 2019-05-07            53021                   69.26      5  2019  642.942796
# 2019-05-08            25157                   60.15      5  2019  642.782646
# 2019-05-09            48953                   72.77      5  2019  642.518087
# 2019-05-10            47078                   53.23      5  2019  642.174597
# 2019-05-13           155350                   63.29      5  2019  641.224835
#
#             Day_Perc_Change                Trend
# Date
# 2017-05-15         0.000000  Slight or No change
# 2017-05-16         0.053485  Slight or No change
# 2017-05-17         0.026576  Slight or No change
# 2017-05-18        -0.026513  Slight or No change
# 2017-05-19         0.028519  Slight or No change
# ...                     ...                  ...
# 2019-05-07        -0.012941  Slight or No change
# 2019-05-08         0.009509  Slight or No change
# 2019-05-09        -0.023833  Slight or No change
# 2019-05-10         0.009211  Slight or No change
# 2019-05-13        -0.000579  Slight or No change
#
# [494 rows x 20 columns]

# %%
# %matplotlib inline
fig,ax=plt.subplots()
data['Close Price'].plot(label = 'MINDAIND',figsize=(16,8),title='Closing Price with respect to Date')
ax.set_ylabel("Price")
plt.legend()

# %%
data['Close Price'].diff().abs().sort_values(ascending = False)
# Out:
# Date
# 2018-07-11    828.65
# 2018-05-23    159.30
# 2018-06-05     92.25
# 2018-02-06     89.20
# 2018-02-12     75.90
#                ...
# 2018-12-13      0.05
# 2018-08-07      0.05
# 2019-01-29      0.05
# 2019-04-25      0.00
# 2017-05-15       NaN
# Name: Close Price, Length: 494, dtype: float64

# %%
import bs4
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests

url_2018_05_23 = 'https://www.business-standard.com/article/markets/minda-industries-soars-10-on-2-1-bonus-issue-strong-q4-results-118052300204_1.html'
r = requests.get(url_2018_05_23)
soup = BeautifulSoup(r.content,"html.parser")
stock_news_title_container = soup.find('title')
stock_news_body_container = soup.find('div',class_ = 'story-content')
print("Obtaining news from Business Standard")
print("News for 2018-05-23")
print('\n')
print("Title:")
print (stock_news_title_container.text)
print("Report:")
print (stock_news_body_container.p.text)

print("-------------------------------------------------------------")

url_2018_06_05 = 'https://www.outlookindia.com/sharemarket/minda-industries-ltd-mindaind-532539/2018-06-05'
r = requests.get(url_2018_06_05)
soup = BeautifulSoup(r.content,"html.parser")
stock_news_title_container = soup.find('div',class_ = 'slug_tag')
stock_news_body_container = soup.find('div',class_ = 'wrapper')
print("Obtaining news from Outlook Money")
print("News for 2018-06-05")
print('\n')
print("Title:")
print (stock_news_title_container.text)
print("Report:")
print (stock_news_body_container.p.text)

print("-------------------------------------------------------------")


url_2018_02_06 = 'https://www.outlookindia.com/stockmarket/minda-industries-ltd-mindaind-532539/2018-02-06'
r = requests.get(url_2018_02_06)
soup = BeautifulSoup(r.content,"html.parser")
stock_news_title_container = soup.find('div',class_ = 'slug_tag')
stock_news_body_container = soup.find('div',class_ = 'wrapper')
print("Obtaining news from Outlook Money")
print("News for 2018-02-06")
print('\n')
print("Title:")
print (stock_news_title_container.text)
print("Report:")
print (stock_news_body_container.p.text)

print("-------------------------------------------------------------")

url_2018_07_11 = 'https://www.outlookindia.com/sharemarket/minda-industries-ltd-mindaind-532539/2018-07-11'
r = requests.get(url_2018_07_11)
soup = BeautifulSoup(r.content,"html.parser")
stock_news_title_container = soup.find('div',class_ = 'slug_tag')
stock_news_body_container = soup.find('div',class_ = 'wrapper')
print("Obtaining news from Outlook Money")
print("News for 2018-07-11")
print('\n')
print("Title:")
print (stock_news_title_container.text)
print("Report:")
print (stock_news_body_container.p.text)

print("-------------------------------------------------------------")

url_2018_02_12 = 'https://www.outlookindia.com/sharemarket/minda-corporation-ltd-mindaind-532539/2018-02-12'
r = requests.get(url_2018_02_12)
soup = BeautifulSoup(r.content,"html.parser")
stock_news_title_container = soup.find('div',class_ = 'slug_tag')
stock_news_body_container = soup.find('div',class_ = 'wrapper')
print("Obtaining news from Outlook Money")
print("News for 2018-02-12")
print('\n')
print("Title:")
print (stock_news_title_container.text)
print("Report:")
print (stock_news_body_container.p.text)

print("-------------------------------------------------------------")
# Out:
# Obtaining news from Business Standard
# News for 2018-05-23
#
#
# Title:
# Minda Industries soars 10% on 2:1 bonus issue; strong Q4 results | Business Standard News
# Report:
# 					    						    						    						    	Minda Industries soared 10% to Rs 1,223 on the BSE after the auto ancillary company said its board recommended bonus shares in the ratio of 2:1. “The board of directors at their meeting held on Tuesday i.e. 22 May, 2018 has recommended the issue of bonus shares to the shareholders of the company in the ratio of 2 bonus equity shares of Rs 2 each fully paid up for every 1 existing equity share of Rs 2 each fully paid up (in the ratio of 2:1) held by the shareholders as on the record date to be fixed separately,” Minda Industries said in a BSE filing.
# -------------------------------------------------------------
# Obtaining news from Outlook Money
# News for 2018-06-05
#
#
# Title:
#
#
# Stock Home  |  June 5, 2018  Last Updated at  16:07:57
#
#
# Report:
#
#
# 		The trading hours came to an end with Minda Industries Ltd.  closing with a price of Rs. 1130.35  after seeing a high of Rs. 1225.15  and a low of Rs. 1111 .
# 	   With this, 117,060  stocks were traded while the 5 day, 10day & 30 day average volumes were observed to be 92,367 , 290,625 , and 132,472  respectively.
# 	   In contrast to previous day’s values, the 5 day average volume fell 9165  stocks, 10 day average volume fell 16364  stocks and 30 day average volume rose 267  stocks.
# 	   In the last 52 weeks the lowest price observed was Rs. 585.90  while the highest price was Rs. 1358.00 .
#
# -------------------------------------------------------------
# Obtaining news from Outlook Money
# News for 2018-02-06
#
#
# Title:
#
#
# Stock Home  |  February 6, 2018  Last Updated at  16:08:17
#
#
# Report:
#
#
# 		The trading hours came to an end with Minda Industries Ltd.  closing with a price of Rs. 1061.2  after seeing a high of Rs. 1136.95  and a low of Rs. 1001 .
# 	   With this, 387,850  stocks were traded while the 5 day, 10day & 30 day average volumes were observed to be 117,733 , 106,472 , and 91,457  respectively.
# 	   The 5 day average volume rose 18739   stocks, 10 day average volume rose 9003  stocks and 30 day average volume rose 2412  stocks as compared to the previous day.
# 	   The 52 week lowest price was Rs. 322.60  while the 52 week highest was Rs. 1358.00 .
#
# -------------------------------------------------------------
# Obtaining news from Outlook Money
# News for 2018-07-11
#
#
# Title:
#
#
# Stock Home  |  July 11, 2018  Last Updated at  16:07:12
#
#
# Report:
#
#
# 		Minda Industries Ltd.  closed at Rs. 418.6  which was 8.6  points more than today's lowest price and 40.4  points less than the day's highest with the day's lowest being Rs. 410  and highest being Rs. 459 .
# 	   With this, 425,963  stocks were traded while the 5 day, 10day & 30 day average volumes were observed to be 82,914 , 71,547 , and 82,629  respectively.
# 	   The 5 day average volume rose 8320   stocks, 10 day average volume rose 5418  stocks and 30 day average volume rose 761  stocks as compared to the previous day.
# 	   The price went up to as much as Rs. 459.00  and went down as low as Rs. 218.31  in the last 52 weeks.
#
# -------------------------------------------------------------
# Obtaining news from Outlook Money
# News for 2018-02-12
#
#
# Title:
#
#
# Stock Home  |   ,   Last Updated at
#
#
# Report:
#
#
# 		The prices of   touched a high of Rs.   which was 0  points more than the opening price after which it closed at Rs.  yesterday.
# 		Also, the lowest price which was Rs.   went 0  points lower than the opening price.
# 		The last volume that was traded was of   stocks and by the end of the day, the 5 day, 10 day & 30 day average volumes were  ,   and    respectively.
# 		The 5 day average volume remained the same as yesterday's  stocks, 10 day average volume remained the same as yesterday's  stocks and 30 day average volume remained the same as yesterday's  stocks in contrast to the previous day’s values.
#
# -------------------------------------------------------------

# %% [markdown]
# ### Query 2.2
#
# A stem plot is a discrete series plot, ideal for plotting daywise data. It can be plotted using the plt.stem() function.
#
# Display a stem plot of the daily change in of the stock price in percentage. This column was calculated in module 1 and should be already available in week2.csv. Observe whenever there's a large change.

# %%
plt.figure(figsize=(20,10))
plt.stem(data.index,data['Day_Perc_Change'])
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# ### Query 2.3
#
# Plot the daily volumes as well and compare the percentage stem plot to it. Document your analysis of the relationship between volume and daily percentage change.

# %%
plt.figure(figsize=(20,10))
plt.stem(data.index,data['Total Traded Quantity'])
# Out:
# <StemContainer object of 3 artists>

# %%
plt.figure(figsize=(20,10))
plt.stem(data['Day_Perc_Change'],data['Total Traded Quantity'])
plt.show()
plt.figure(figsize=(20,10))
plt.stem(data['Total Traded Quantity'],data['Day_Perc_Change'])
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(data['Day_Perc_Change'],data['Total Traded Quantity'])
plt.show()
plt.figure(figsize=(20,10))
plt.plot(data['Total Traded Quantity'],data['Day_Perc_Change'])
plt.show()

# %% [markdown]
# ### Query 2.4
# We had created a Trend column in module 1. We want to see how often each Trend type occurs. This can be seen as a pie chart, with each sector representing the percentage of days each trend occurs. Plot a pie chart for all the 'Trend' to know about relative frequency of each trend. You can use the groupby function with the trend column to group all days with the same trend into a single group before plotting the pie chart. From the grouped data, create a BAR plot of average & median values of the 'Total Traded Quantity' by Trend type.

# %%
from collections import Counter

Trendsare = ['Postive','Negative','Breakout Bull','Breakout Bear','Among top losers','Among top gainers','Slight or No Change','Slight Positive','Slight Negative']
Trend_to_list = data['Trend'].tolist()
counts = Counter(Trend_to_list)
counts
# Out:
# Counter({'Slight or No change': 494})

# %%
counter = [494]
labels= ['Slight or No change']
colors = ['r']
plt.figure(figsize=(20,10))
plt.pie(counter, labels=labels,colors=colors,startangle=90, autopct='%.1f%%')
plt.show()

# %%
gk = data.groupby(['Trend'])['Total Traded Quantity']
gk.describe()
# Out:
#                      count           mean            std     min       25%  \
# Trend
# Slight or No change  494.0  155488.180162  189770.174628  8188.0  67197.25
#
#                           50%       75%        max
# Trend
# Slight or No change  104944.0  173996.5  2335284.0

# %%
plt.figure(figsize=(20,10))
data.groupby(['Trend'])['Total Traded Quantity'].mean().plot.bar()

# %%
plt.figure(figsize=(20,10))
data.groupby(['Trend'])['Total Traded Quantity'].median().plot.bar()

# %% [markdown]
# ### Query 2.5
# Plot the daily return (percentage) distribution as a histogram.
# Histogram analysis is one of the most fundamental methods of exploratory data analysis. In this case, it'd return a frequency plot of various values of percentage changes.

# %%
plt.figure(figsize=(20,10))
plt.hist(data['Day_Perc_Change'])
plt.show()

# %% [markdown]
# ### Query 2.6
# We next want to analyse how the behaviour of different stocks are correlated. The correlation is performed on the percentage change of the stock price instead of the stock price.
#
# Load any 5 stocks of your choice into 5 dataframes. Retain only rows for which ‘Series’ column has value ‘EQ’. Create a single dataframe which contains the ‘Closing Price’ of each stock. This dataframe should hence have five columns. Rename each column to the name of the stock that is contained in the column. Create a new dataframe which is a percentage change of the values in the previous dataframe. Drop Nan’s from this dataframe.
# Using seaborn, analyse the correlation between the percentage changes in the five stocks. This is extremely useful for a fund manager to design a diversified portfolio. To know more, check out these resources on correlation and diversification.

# %%
SUNPHARMA_data = pd.read_csv('SUNPHARMA.csv')
TITAN_data = pd.read_csv('TITAN.csv')
ASIANPAINT_data = pd.read_csv('ASIANPAINT.csv')
MARUTI_data = pd.read_csv('MARUTI.csv')
AXISBANK_data = pd.read_csv('AXISBANK.csv')

# %%
SUNPHARMA_data
# Out:
#         Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    SUNPHARMA     EQ  15-May-2017      655.10      655.40      656.85
# 1    SUNPHARMA     EQ  16-May-2017      654.45      655.00      656.55
# 2    SUNPHARMA     EQ  17-May-2017      652.35      652.10      653.00
# 3    SUNPHARMA     EQ  18-May-2017      650.90      648.70      655.25
# 4    SUNPHARMA     EQ  19-May-2017      653.95      655.50      656.95
# ..         ...    ...          ...         ...         ...         ...
# 490  SUNPHARMA     EQ  07-May-2019      453.15      456.00      456.00
# 491  SUNPHARMA     EQ  08-May-2019      448.20      447.75      449.85
# 492  SUNPHARMA     EQ  09-May-2019      439.15      436.00      442.70
# 493  SUNPHARMA     EQ  10-May-2019      439.35      437.00      442.65
# 494  SUNPHARMA     EQ  13-May-2019      437.75      437.75      437.75
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       649.50      654.00       654.45         653.97                1224004
# 1       648.00      650.00       652.35         652.01                2325051
# 2       644.10      652.00       650.90         648.50                1920624
# 3       643.45      655.00       653.95         651.53                2149513
# 4       646.70      652.00       653.15         652.63                2223401
# ..         ...         ...          ...            ...                    ...
# 490     446.45      447.25       448.20         451.60                4189396
# 491     433.45      436.00       439.15         440.90                4885249
# 492     431.55      439.25       439.35         437.60                3550114
# 493     434.45      437.65       437.75         438.38                3482485
# 494     344.55      414.00       398.10         401.07               24079258
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    8.004617e+08          35100           846103                   69.13
# 1    1.515959e+09          47246          1790950                   77.03
# 2    1.245520e+09          50402          1418894                   73.88
# 3    1.400465e+09          31259          1504397                   69.99
# 4    1.451054e+09          91126          1471827                   66.20
# ..            ...            ...              ...                     ...
# 490  1.891916e+09          60790          2021138                   48.24
# 491  2.153904e+09          74176          1930369                   39.51
# 492  1.553525e+09          57904          1063280                   29.95
# 493  1.526655e+09          62727          1313912                   37.73
# 494  9.657555e+09         260840          6844309                   28.42
#
# [495 rows x 15 columns]

# %%
TITAN_data
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0    TITAN     EQ  15-May-2017      495.00      489.65      490.00     472.40
# 1    TITAN     EQ  16-May-2017      483.65      486.00      491.00     480.80
# 2    TITAN     EQ  17-May-2017      488.30      490.00      490.10     477.30
# 3    TITAN     EQ  18-May-2017      481.75      479.00      482.60     470.05
# 4    TITAN     EQ  19-May-2017      471.65      475.00      479.50     460.35
# ..     ...    ...          ...         ...         ...         ...        ...
# 491  TITAN     EQ  07-May-2019     1082.85     1097.80     1105.00    1083.00
# 492  TITAN     EQ  08-May-2019     1086.50     1090.00     1100.00    1067.85
# 493  TITAN     EQ  09-May-2019     1088.70     1100.00     1110.00    1088.70
# 494  TITAN     EQ  10-May-2019     1104.45     1108.00     1137.85    1094.30
# 495  TITAN     EQ  13-May-2019     1132.10     1125.30     1152.80    1124.05
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0        486.00       483.65         479.93                3897357
# 1        490.00       488.30         487.32                1308863
# 2        481.00       481.75         482.25                 859054
# 3        470.85       471.65         474.78                 811219
# 4        469.65       471.15         469.05                1022479
# ..          ...          ...            ...                    ...
# 491     1090.00      1086.50        1094.54                2605643
# 492     1096.80      1088.70        1085.83                3336769
# 493     1103.20      1104.45        1099.15                4362293
# 494     1129.45      1132.10        1117.09                3032624
# 495     1149.00      1144.70        1144.23                2695155
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    1.870465e+09          52478          1722661                   44.20
# 1    6.378316e+08          33942           563667                   43.07
# 2    4.142814e+08          26686           448314                   52.19
# 3    3.851526e+08          24621           438716                   54.08
# 4    4.795891e+08          27225           263561                   25.78
# ..            ...            ...              ...                     ...
# 491  2.851972e+09          83154           507973                   19.50
# 492  3.623149e+09          92788           472241                   14.15
# 493  4.794807e+09         131781           751092                   17.22
# 494  3.387712e+09         101440          1044911                   34.46
# 495  3.083875e+09          97460           804550                   29.85
#
# [496 rows x 15 columns]

# %%
MARUTI_data
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    MARUTI     EQ  15-May-2017     6730.20      6759.4     6839.10
# 1    MARUTI     EQ  16-May-2017     6823.90      6850.0     6977.55
# 2    MARUTI     EQ  17-May-2017     6953.95      6950.0     6979.00
# 3    MARUTI     EQ  18-May-2017     6958.20      6918.3     6948.00
# 4    MARUTI     EQ  19-May-2017     6831.05      6854.8     6893.90
# ..      ...    ...          ...         ...         ...         ...
# 491  MARUTI     EQ  07-May-2019     6709.65      6744.9     6785.25
# 492  MARUTI     EQ  08-May-2019     6702.00      6679.0     6693.00
# 493  MARUTI     EQ  09-May-2019     6650.15      6637.0     6678.00
# 494  MARUTI     EQ  10-May-2019     6624.95      6623.0     6664.90
# 495  MARUTI     EQ  13-May-2019     6631.60      6626.0     6659.30
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      6733.45     6824.00      6823.90        6796.84                 336356
# 1      6830.00     6968.40      6953.95        6902.22                 707624
# 2      6885.85     6945.00      6958.20        6931.60                 445461
# 3      6814.45     6822.00      6831.05        6869.68                 406814
# 4      6691.55     6756.30      6790.55        6791.60                 552223
# ..         ...         ...          ...            ...                    ...
# 491    6680.00     6693.00      6702.00        6737.56                 586684
# 492    6616.00     6650.00      6650.15        6655.70                 552749
# 493    6600.00     6609.85      6624.95        6646.86                 570000
# 494    6575.00     6630.00      6631.60        6622.41                 608669
# 495    6500.00     6523.00      6543.75        6603.04                 555672
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    2.286158e+09          31377           154743                   46.01
# 1    4.884174e+09          49047           360641                   50.97
# 2    3.087758e+09          65280           260033                   58.37
# 3    2.794684e+09          37063           188907                   46.44
# 4    3.750475e+09          64293           234662                   42.49
# ..            ...            ...              ...                     ...
# 491  3.952821e+09          69696           198757                   33.88
# 492  3.678929e+09          59897           228920                   41.41
# 493  3.788710e+09          71334           257451                   45.17
# 494  4.030855e+09          75423           247688                   40.69
# 495  3.669123e+09          74137           241880                   43.53
#
# [496 rows x 15 columns]

# %%
AXISBANK_data
# Out:
#        Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    AXISBANK     EQ  15-May-2017      503.00      505.00      508.50
# 1    AXISBANK     EQ  16-May-2017      500.10      502.10      504.50
# 2    AXISBANK     EQ  17-May-2017      501.50      501.35      506.75
# 3    AXISBANK     EQ  18-May-2017      502.80      498.00      499.10
# 4    AXISBANK     EQ  19-May-2017      492.00      495.75      503.85
# ..        ...    ...          ...         ...         ...         ...
# 490  AXISBANK     EQ  07-May-2019      747.45      751.85      755.50
# 491  AXISBANK     EQ  08-May-2019      741.85      741.90      744.75
# 492  AXISBANK     EQ  09-May-2019      735.50      733.90      740.50
# 493  AXISBANK     EQ  10-May-2019      731.00      734.40      738.50
# 494  AXISBANK     EQ  13-May-2019      735.05      734.00      742.85
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       498.40      500.25       500.10         502.95                8806756
# 1       493.50      502.05       501.50         499.85                8610492
# 2       498.50      502.00       502.80         502.88                6443135
# 3       490.25      492.85       492.00         494.96                9227022
# 4       494.20      501.90       501.70         499.10                7611430
# ..         ...         ...          ...            ...                    ...
# 490     740.00      744.85       741.85         748.48                5071941
# 491     733.35      735.10       735.50         737.58                6739894
# 492     729.40      732.35       731.00         734.60                4193451
# 493     729.50      732.55       735.05         735.71                3913815
# 494     730.00      732.00       732.10         736.74                5891071
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    4.429384e+09         109965          4320438                   49.06
# 1    4.303938e+09         101028          4027982                   46.78
# 2    3.240154e+09          84189          2876528                   44.64
# 3    4.566993e+09          95624          5348691                   57.97
# 4    3.798900e+09          72985          4190505                   55.06
# ..            ...            ...              ...                     ...
# 490  3.796226e+09         141094          2404026                   47.40
# 491  4.971211e+09         118950          3373685                   50.06
# 492  3.080497e+09          75621          1409191                   33.60
# 493  2.879428e+09         114875          1569735                   40.11
# 494  4.340174e+09         142075          2615724                   44.40
#
# [495 rows x 15 columns]

# %%
ASIANPAINT_data
# Out:
#          Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    ASIANPAINT     EQ  15-May-2017     1132.95     1142.90     1149.90
# 1    ASIANPAINT     EQ  16-May-2017     1148.05     1148.90     1149.70
# 2    ASIANPAINT     EQ  17-May-2017     1142.85     1143.00     1159.00
# 3    ASIANPAINT     EQ  18-May-2017     1154.95     1147.15     1159.80
# 4    ASIANPAINT     EQ  19-May-2017     1151.35     1139.85     1144.80
# ..          ...    ...          ...         ...         ...         ...
# 490  ASIANPAINT     EQ  07-May-2019     1412.80     1426.80     1426.80
# 491  ASIANPAINT     EQ  08-May-2019     1387.80     1382.00     1395.00
# 492  ASIANPAINT     EQ  09-May-2019     1385.70     1384.95     1393.65
# 493  ASIANPAINT     EQ  10-May-2019     1354.20     1314.10     1350.00
# 494  ASIANPAINT     EQ  13-May-2019     1341.05     1341.05     1345.25
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      1135.00     1149.90      1148.05        1145.57                 729473
# 1      1129.60     1143.50      1142.85        1137.20                 913600
# 2      1136.55     1156.75      1154.95        1149.76                 579709
# 3      1140.00     1154.80      1151.35        1149.89                 702003
# 4      1098.80     1131.00      1123.15        1124.84                1732673
# ..         ...         ...          ...            ...                    ...
# 490    1376.35     1391.00      1387.80        1396.83                2863939
# 491    1362.60     1395.00      1385.70        1379.52                1414591
# 492    1346.55     1350.00      1354.20        1367.60                2628463
# 493    1314.10     1345.00      1341.05        1335.23                3476379
# 494    1323.65     1336.55      1332.50        1332.02                 862130
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    8.356654e+08          20868           471377                   64.62
# 1    1.038946e+09          35436           641893                   70.26
# 2    6.665239e+08          24824           282528                   48.74
# 3    8.072265e+08          23468           436095                   62.12
# 4    1.948986e+09          87720          1021656                   58.96
# ..            ...            ...              ...                     ...
# 490  4.000437e+09          78177          1822508                   63.64
# 491  1.951463e+09          40321           860170                   60.81
# 492  3.594676e+09          89032           998318                   37.98
# 493  4.641774e+09         143729          1638493                   47.13
# 494  1.148376e+09          55173           462186                   53.61
#
# [495 rows x 15 columns]

# %%
final_SUNPHARMA = SUNPHARMA_data[SUNPHARMA_data.Series == 'EQ']
final_SUNPHARMA
# Out:
#         Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    SUNPHARMA     EQ  15-May-2017      655.10      655.40      656.85
# 1    SUNPHARMA     EQ  16-May-2017      654.45      655.00      656.55
# 2    SUNPHARMA     EQ  17-May-2017      652.35      652.10      653.00
# 3    SUNPHARMA     EQ  18-May-2017      650.90      648.70      655.25
# 4    SUNPHARMA     EQ  19-May-2017      653.95      655.50      656.95
# ..         ...    ...          ...         ...         ...         ...
# 490  SUNPHARMA     EQ  07-May-2019      453.15      456.00      456.00
# 491  SUNPHARMA     EQ  08-May-2019      448.20      447.75      449.85
# 492  SUNPHARMA     EQ  09-May-2019      439.15      436.00      442.70
# 493  SUNPHARMA     EQ  10-May-2019      439.35      437.00      442.65
# 494  SUNPHARMA     EQ  13-May-2019      437.75      437.75      437.75
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       649.50      654.00       654.45         653.97                1224004
# 1       648.00      650.00       652.35         652.01                2325051
# 2       644.10      652.00       650.90         648.50                1920624
# 3       643.45      655.00       653.95         651.53                2149513
# 4       646.70      652.00       653.15         652.63                2223401
# ..         ...         ...          ...            ...                    ...
# 490     446.45      447.25       448.20         451.60                4189396
# 491     433.45      436.00       439.15         440.90                4885249
# 492     431.55      439.25       439.35         437.60                3550114
# 493     434.45      437.65       437.75         438.38                3482485
# 494     344.55      414.00       398.10         401.07               24079258
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    8.004617e+08          35100           846103                   69.13
# 1    1.515959e+09          47246          1790950                   77.03
# 2    1.245520e+09          50402          1418894                   73.88
# 3    1.400465e+09          31259          1504397                   69.99
# 4    1.451054e+09          91126          1471827                   66.20
# ..            ...            ...              ...                     ...
# 490  1.891916e+09          60790          2021138                   48.24
# 491  2.153904e+09          74176          1930369                   39.51
# 492  1.553525e+09          57904          1063280                   29.95
# 493  1.526655e+09          62727          1313912                   37.73
# 494  9.657555e+09         260840          6844309                   28.42
#
# [494 rows x 15 columns]

# %%
final_MARUTI = MARUTI_data[MARUTI_data.Series == 'EQ']
final_MARUTI
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    MARUTI     EQ  15-May-2017     6730.20      6759.4     6839.10
# 1    MARUTI     EQ  16-May-2017     6823.90      6850.0     6977.55
# 2    MARUTI     EQ  17-May-2017     6953.95      6950.0     6979.00
# 3    MARUTI     EQ  18-May-2017     6958.20      6918.3     6948.00
# 4    MARUTI     EQ  19-May-2017     6831.05      6854.8     6893.90
# ..      ...    ...          ...         ...         ...         ...
# 491  MARUTI     EQ  07-May-2019     6709.65      6744.9     6785.25
# 492  MARUTI     EQ  08-May-2019     6702.00      6679.0     6693.00
# 493  MARUTI     EQ  09-May-2019     6650.15      6637.0     6678.00
# 494  MARUTI     EQ  10-May-2019     6624.95      6623.0     6664.90
# 495  MARUTI     EQ  13-May-2019     6631.60      6626.0     6659.30
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      6733.45     6824.00      6823.90        6796.84                 336356
# 1      6830.00     6968.40      6953.95        6902.22                 707624
# 2      6885.85     6945.00      6958.20        6931.60                 445461
# 3      6814.45     6822.00      6831.05        6869.68                 406814
# 4      6691.55     6756.30      6790.55        6791.60                 552223
# ..         ...         ...          ...            ...                    ...
# 491    6680.00     6693.00      6702.00        6737.56                 586684
# 492    6616.00     6650.00      6650.15        6655.70                 552749
# 493    6600.00     6609.85      6624.95        6646.86                 570000
# 494    6575.00     6630.00      6631.60        6622.41                 608669
# 495    6500.00     6523.00      6543.75        6603.04                 555672
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    2.286158e+09          31377           154743                   46.01
# 1    4.884174e+09          49047           360641                   50.97
# 2    3.087758e+09          65280           260033                   58.37
# 3    2.794684e+09          37063           188907                   46.44
# 4    3.750475e+09          64293           234662                   42.49
# ..            ...            ...              ...                     ...
# 491  3.952821e+09          69696           198757                   33.88
# 492  3.678929e+09          59897           228920                   41.41
# 493  3.788710e+09          71334           257451                   45.17
# 494  4.030855e+09          75423           247688                   40.69
# 495  3.669123e+09          74137           241880                   43.53
#
# [494 rows x 15 columns]

# %%
final_AXISBANK = AXISBANK_data[AXISBANK_data.Series == 'EQ']
final_AXISBANK
# Out:
#        Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    AXISBANK     EQ  15-May-2017      503.00      505.00      508.50
# 1    AXISBANK     EQ  16-May-2017      500.10      502.10      504.50
# 2    AXISBANK     EQ  17-May-2017      501.50      501.35      506.75
# 3    AXISBANK     EQ  18-May-2017      502.80      498.00      499.10
# 4    AXISBANK     EQ  19-May-2017      492.00      495.75      503.85
# ..        ...    ...          ...         ...         ...         ...
# 490  AXISBANK     EQ  07-May-2019      747.45      751.85      755.50
# 491  AXISBANK     EQ  08-May-2019      741.85      741.90      744.75
# 492  AXISBANK     EQ  09-May-2019      735.50      733.90      740.50
# 493  AXISBANK     EQ  10-May-2019      731.00      734.40      738.50
# 494  AXISBANK     EQ  13-May-2019      735.05      734.00      742.85
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       498.40      500.25       500.10         502.95                8806756
# 1       493.50      502.05       501.50         499.85                8610492
# 2       498.50      502.00       502.80         502.88                6443135
# 3       490.25      492.85       492.00         494.96                9227022
# 4       494.20      501.90       501.70         499.10                7611430
# ..         ...         ...          ...            ...                    ...
# 490     740.00      744.85       741.85         748.48                5071941
# 491     733.35      735.10       735.50         737.58                6739894
# 492     729.40      732.35       731.00         734.60                4193451
# 493     729.50      732.55       735.05         735.71                3913815
# 494     730.00      732.00       732.10         736.74                5891071
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    4.429384e+09         109965          4320438                   49.06
# 1    4.303938e+09         101028          4027982                   46.78
# 2    3.240154e+09          84189          2876528                   44.64
# 3    4.566993e+09          95624          5348691                   57.97
# 4    3.798900e+09          72985          4190505                   55.06
# ..            ...            ...              ...                     ...
# 490  3.796226e+09         141094          2404026                   47.40
# 491  4.971211e+09         118950          3373685                   50.06
# 492  3.080497e+09          75621          1409191                   33.60
# 493  2.879428e+09         114875          1569735                   40.11
# 494  4.340174e+09         142075          2615724                   44.40
#
# [494 rows x 15 columns]

# %%
final_ASIANPAINT = ASIANPAINT_data[ASIANPAINT_data.Series == 'EQ']
final_ASIANPAINT
# Out:
#          Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    ASIANPAINT     EQ  15-May-2017     1132.95     1142.90     1149.90
# 1    ASIANPAINT     EQ  16-May-2017     1148.05     1148.90     1149.70
# 2    ASIANPAINT     EQ  17-May-2017     1142.85     1143.00     1159.00
# 3    ASIANPAINT     EQ  18-May-2017     1154.95     1147.15     1159.80
# 4    ASIANPAINT     EQ  19-May-2017     1151.35     1139.85     1144.80
# ..          ...    ...          ...         ...         ...         ...
# 490  ASIANPAINT     EQ  07-May-2019     1412.80     1426.80     1426.80
# 491  ASIANPAINT     EQ  08-May-2019     1387.80     1382.00     1395.00
# 492  ASIANPAINT     EQ  09-May-2019     1385.70     1384.95     1393.65
# 493  ASIANPAINT     EQ  10-May-2019     1354.20     1314.10     1350.00
# 494  ASIANPAINT     EQ  13-May-2019     1341.05     1341.05     1345.25
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      1135.00     1149.90      1148.05        1145.57                 729473
# 1      1129.60     1143.50      1142.85        1137.20                 913600
# 2      1136.55     1156.75      1154.95        1149.76                 579709
# 3      1140.00     1154.80      1151.35        1149.89                 702003
# 4      1098.80     1131.00      1123.15        1124.84                1732673
# ..         ...         ...          ...            ...                    ...
# 490    1376.35     1391.00      1387.80        1396.83                2863939
# 491    1362.60     1395.00      1385.70        1379.52                1414591
# 492    1346.55     1350.00      1354.20        1367.60                2628463
# 493    1314.10     1345.00      1341.05        1335.23                3476379
# 494    1323.65     1336.55      1332.50        1332.02                 862130
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    8.356654e+08          20868           471377                   64.62
# 1    1.038946e+09          35436           641893                   70.26
# 2    6.665239e+08          24824           282528                   48.74
# 3    8.072265e+08          23468           436095                   62.12
# 4    1.948986e+09          87720          1021656                   58.96
# ..            ...            ...              ...                     ...
# 490  4.000437e+09          78177          1822508                   63.64
# 491  1.951463e+09          40321           860170                   60.81
# 492  3.594676e+09          89032           998318                   37.98
# 493  4.641774e+09         143729          1638493                   47.13
# 494  1.148376e+09          55173           462186                   53.61
#
# [494 rows x 15 columns]

# %%
final_TITAN = TITAN_data[TITAN_data.Series == 'EQ']
final_TITAN
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0    TITAN     EQ  15-May-2017      495.00      489.65      490.00     472.40
# 1    TITAN     EQ  16-May-2017      483.65      486.00      491.00     480.80
# 2    TITAN     EQ  17-May-2017      488.30      490.00      490.10     477.30
# 3    TITAN     EQ  18-May-2017      481.75      479.00      482.60     470.05
# 4    TITAN     EQ  19-May-2017      471.65      475.00      479.50     460.35
# ..     ...    ...          ...         ...         ...         ...        ...
# 491  TITAN     EQ  07-May-2019     1082.85     1097.80     1105.00    1083.00
# 492  TITAN     EQ  08-May-2019     1086.50     1090.00     1100.00    1067.85
# 493  TITAN     EQ  09-May-2019     1088.70     1100.00     1110.00    1088.70
# 494  TITAN     EQ  10-May-2019     1104.45     1108.00     1137.85    1094.30
# 495  TITAN     EQ  13-May-2019     1132.10     1125.30     1152.80    1124.05
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0        486.00       483.65         479.93                3897357
# 1        490.00       488.30         487.32                1308863
# 2        481.00       481.75         482.25                 859054
# 3        470.85       471.65         474.78                 811219
# 4        469.65       471.15         469.05                1022479
# ..          ...          ...            ...                    ...
# 491     1090.00      1086.50        1094.54                2605643
# 492     1096.80      1088.70        1085.83                3336769
# 493     1103.20      1104.45        1099.15                4362293
# 494     1129.45      1132.10        1117.09                3032624
# 495     1149.00      1144.70        1144.23                2695155
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    1.870465e+09          52478          1722661                   44.20
# 1    6.378316e+08          33942           563667                   43.07
# 2    4.142814e+08          26686           448314                   52.19
# 3    3.851526e+08          24621           438716                   54.08
# 4    4.795891e+08          27225           263561                   25.78
# ..            ...            ...              ...                     ...
# 491  2.851972e+09          83154           507973                   19.50
# 492  3.623149e+09          92788           472241                   14.15
# 493  4.794807e+09         131781           751092                   17.22
# 494  3.387712e+09         101440          1044911                   34.46
# 495  3.083875e+09          97460           804550                   29.85
#
# [494 rows x 15 columns]

# %%
import pandas as pd

columns = ['TITAN','ASIANPAINT','AXISBANK','MARUTI','SUNPHARMA']
close_prices_dataFrame = pd.DataFrame(columns = columns)
close_prices_dataFrame['TITAN'] = final_TITAN['Close Price']
close_prices_dataFrame['ASIANPAINT'] = final_ASIANPAINT['Close Price']
close_prices_dataFrame['MARUTI'] = final_MARUTI['Close Price']
close_prices_dataFrame['SUNPHARMA'] = final_SUNPHARMA['Close Price']
close_prices_dataFrame['AXISBANK'] = final_AXISBANK['Close Price']
close_prices_dataFrame.dropna()
# Out:
#        TITAN  ASIANPAINT  AXISBANK   MARUTI  SUNPHARMA
# 0     483.65     1148.05    500.10  6823.90     654.45
# 1     488.30     1142.85    501.50  6953.95     652.35
# 2     481.75     1154.95    502.80  6958.20     650.90
# 3     471.65     1151.35    492.00  6831.05     653.95
# 4     471.15     1123.15    501.70  6790.55     653.15
# ..       ...         ...       ...      ...        ...
# 490  1082.85     1387.80    741.85  6709.65     448.20
# 491  1086.50     1385.70    735.50  6702.00     439.15
# 492  1088.70     1354.20    731.00  6650.15     439.35
# 493  1104.45     1341.05    735.05  6624.95     437.75
# 494  1132.10     1332.50    732.10  6631.60     398.10
#
# [490 rows x 5 columns]

# %%
pct_change_dataFrame = close_prices_dataFrame.pct_change().fillna(0)
pct_change_dataFrame.dropna()
# Out:
#         TITAN  ASIANPAINT  AXISBANK    MARUTI  SUNPHARMA
# 0    0.000000    0.000000  0.000000  0.000000   0.000000
# 1    0.009614   -0.004529  0.002799  0.019058  -0.003209
# 2   -0.013414    0.010588  0.002592  0.000611  -0.002223
# 3   -0.020965   -0.003117 -0.021480 -0.018273   0.004686
# 4   -0.001060   -0.024493  0.019715 -0.005929  -0.001223
# ..        ...         ...       ...       ...        ...
# 491  0.003371   -0.001513 -0.008560 -0.001140  -0.020192
# 492  0.002025   -0.022732 -0.006118 -0.007736   0.000455
# 493  0.014467   -0.009711  0.005540 -0.003789  -0.003642
# 494  0.025035   -0.006376 -0.004013  0.001004  -0.090577
# 495  0.011130    0.000000  0.000000 -0.013247   0.000000
#
# [494 rows x 5 columns]

# %%
import seaborn as sns

sns.set(color_codes=True)
sns.pairplot(pct_change_dataFrame)

# %% [markdown]
# ### Query 2.7
# Volatility is the change in variance in the returns of a stock over a specific period of time.Do give the following documentation on volatility a read.
# You have already calculated the percentage changes in several stock prices. Calculate the 7 day rolling average of the percentage change of any of the stock prices, then compute the standard deviation (which is the square root of the variance) and plot the values.
# Note: pandas provides a rolling() function for dataframes and a std() function also which you can use.

# %%
import matplotlib.pyplot as plt
rolling_avg_MARUTI = pct_change_dataFrame['MARUTI'].rolling(7).mean()

# %%
stand_MARUTI = rolling_avg_MARUTI.fillna(0).std()
stand_MARUTI
# Out:
# 0.005773321322779078

# %%
crrDate = pd.to_datetime(final_MARUTI['Date'])
crrLis = crrDate.tolist()
plt.figure(figsize=(20,10))
plt.plot(crrLis,rolling_avg_MARUTI.fillna(0).tolist())
plt.show()

# %% [markdown]
# ### Query 2.8
# Calculate the volatility for the Nifty index and compare the 2. This leads us to a useful indicator known as 'Beta' ( We'll be covering this in length in Module 3)

# %%
nifty_load = pd.read_csv('NIFTY_50.csv')
nifty_load
# Out:
#             Date      Open      High       Low     Close  Shares Traded  \
# 0    15-May-2017   9433.55   9449.25   9423.10   9445.40      145163953
# 1    16-May-2017   9461.00   9517.20   9456.35   9512.25      171709433
# 2    17-May-2017   9517.60   9532.60   9486.10   9525.75      211856040
# 3    18-May-2017   9453.20   9489.10   9418.10   9429.45      199340647
# 4    19-May-2017   9469.90   9505.75   9390.75   9427.90      259861396
# ..           ...       ...       ...       ...       ...            ...
# 489  07-May-2019  11651.50  11657.05  11484.45  11497.90      337495624
# 490  08-May-2019  11478.70  11479.10  11346.95  11359.45      372826025
# 491  09-May-2019  11322.40  11357.60  11255.05  11301.80      373028059
# 492  10-May-2019  11314.15  11345.80  11251.05  11278.90      387323416
# 493  13-May-2019  11258.70  11300.20  11125.60  11148.20      357586433
#
#      Turnover (Rs. Cr)
# 0              7790.97
# 1              9209.89
# 2             10726.23
# 3             10782.46
# 4             11544.77
# ..                 ...
# 489           16632.84
# 490           17440.01
# 491           17602.86
# 492           18085.19
# 493           16722.91
#
# [494 rows x 7 columns]

# %%
nif_close_price = nifty_load['Close']
nif_change = nif_close_price.pct_change().fillna(0).rolling(7).mean().fillna(0)
nifDate = pd.to_datetime(nifty_load['Date'])
nifDate = nifDate.tolist()
plt.figure(figsize=(20,10))

TITAN_Date = pd.to_datetime(final_TITAN['Date'])
TITANLis = TITAN_Date.tolist()
TITAN_close_price = final_TITAN['Close Price']
TITAN_change = TITAN_close_price.pct_change().fillna(0).rolling(7).mean().fillna(0)
plt.figure(figsize=(20,10))
plt.plot(TITANLis,rolling_avg_MARUTI.fillna(0).tolist())

plt.title("Volatility of NIFTY with respect to TITAN and MARUTI")
plt.plot(nifDate,nif_change.tolist(),label = 'nifty')
plt.plot(crrLis,rolling_avg_MARUTI.fillna(0).tolist(),label = 'MARUTI')
plt.plot(TITANLis,TITAN_change,label = 'TITAN')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Query 2.9
# Trade Calls - Using Simple Moving Averages. Study about moving averages here.Plot the 21 day and 34 day Moving average with the average price and decide a Call !
# Call should be buy whenever the smaller moving average (21) crosses over longer moving average (34) AND the call should be sell whenever smaller moving average crosses under longer moving average.
# One of the most widely used technical indicators.

# %%
plt.figure(figsize=(20,10))
plt.plot(TITANLis,TITAN_change,label = 'TITAN')
plt.legend(loc='upper left')
plt.show()

# %%
short_window = 21
long_window = 34

signals = pd.DataFrame(index=final_TITAN.index)
signals['signal'] = 0.0
signals['short_mavg'] = final_TITAN['Close Price'].rolling(window=short_window, min_periods=1,center=False).mean()
signals['long_mavg'] = final_TITAN['Close Price'].rolling(window=long_window,min_periods=1, center=False).mean()
signals['signal'][short_window:] = np.where(signals['short_mavg'][short_window:] > signals['long_mavg'][short_window:], 1.0,0.0)
signals['positions'] = signals['signal'].diff()
print(signals)
# Out:
#      signal   short_mavg    long_mavg  positions
# 0       0.0   483.650000   483.650000        NaN
# 1       0.0   485.975000   485.975000        0.0
# 2       0.0   484.566667   484.566667        0.0
# 3       0.0   481.337500   481.337500        0.0
# 4       0.0   479.300000   479.300000        0.0
# ..      ...          ...          ...        ...
# 491     1.0  1116.480952  1114.283824        0.0
# 492     1.0  1115.919048  1114.352941        0.0
# 493     1.0  1115.840476  1114.564706        0.0
# 494     1.0  1117.064286  1115.470588        0.0
# 495     1.0  1118.983333  1116.519118        0.0
#
# [494 rows x 4 columns]

# %%
fig = plt.figure(figsize=(20,15))
ax1 = fig.add_subplot(111, ylabel='Price')
final_TITAN['Close Price'].plot(ax=ax1, color='black', lw=2.)
signals[['short_mavg', 'long_mavg']].plot(ax=ax1, lw=2.)
ax1.plot(signals.loc[signals.positions == 1.0].index, signals.short_mavg[signals.positions == 1.0], '^' , markersize=20,color='g')
ax1.plot(signals.loc[signals.positions == -1.0].index, signals.short_mavg[signals.positions == -1.0], 'v' , markersize=20,color='r')
plt.show()

# %% [markdown]
# ## 2.10 Trade Calls - Using Bollinger Bands
# Plot the bollinger bands for this stock - the duration of 14 days and 2 standard deviations away from the average
# The bollinger bands comprise the following data points-
# The 14 day rolling mean of the closing price (we call it the average)
# Upper band which is the rolling mean + 2 standard deviations away from the average.
# Lower band which is the rolling mean - 2 standard deviations away from the average.
# Average Daily stock price.
# Bollinger bands are extremely reliable , with a 95% accuracy at 2 standard deviations , and especially useful in sideways moving market.
# Observe the bands yourself , and analyse the accuracy of all the trade signals provided by the bollinger bands.
# Save to a new csv file.

# %%
symbol = 'TITAN'
df = pd.read_csv('TITAN.csv'.format(symbol), index_col='Date',
                 parse_dates=True, usecols=['Date', 'Close Price'],
                 na_values='nan')
df = df.rename(columns={'Close Price': symbol})
df.dropna(inplace=True)
sma = df.rolling(window=14).mean()
rstd = df.rolling(window=14).std()
upper_band = sma + 2 * rstd
upper_band = upper_band.rename(columns={symbol: 'upper'})
lower_band = sma - 2 * rstd
lower_band = lower_band.rename(columns={symbol: 'lower'})
df = df.join(upper_band).join(lower_band)
ax = df.plot(title='{} Price and BB'.format(symbol))
ax.set_xlabel('Date')
ax.set_ylabel('SMA and BB')
ax.grid()
plt.show()
